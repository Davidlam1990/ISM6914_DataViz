# %%
import pandas as pd
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Create the bin dividers
bins = [0, 60, 70, 80, 90, 100]
# Create names for the four groups
group_names = ['F', 'D', 'C', 'B', 'A']

# %%
df['lettergrade'] = pd.cut(df['grade'], bins,labels=group_names)
df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address lettergrade
# 0         9253 Richardson Road, Matawan, NJ 07747           B
# 1                33 Spring Dr., Taunton, MA 02780           C
# 2                41 Hill Avenue, Mentor, OH 44060           C
# 3              8839 Marshall St., Miami, FL 33125           B
# 4        8304 Charles Rd., Lewis Center, OH 43035           B
# ...                                           ...         ...
# 1995        982 West Street, Alexandria, VA 22304           B
# 1996   78 Morris Street, East Northport, NY 11731           A
# 1997        30 Glenridge Rd., Bountiful, UT 84010           B
# 1998  342 West Meadowbrook Lane, Helena, MT 59601           D
# 1999       81 Homestead Drive, Voorhees, NJ 08043           C
#
# [2000 rows x 9 columns]

# %%
pd.value_counts(df['lettergrade'])
# Out:
# B    737
# C    580
# A    475
# D    193
# F     15
# Name: lettergrade, dtype: int64

# %%
# Your Turn
# Create the bin dividers
bins = [0,80,100]
# Create names for the four groups
group_names = ['Fail','Pass']

# %%
df['Status'] = pd.cut(df['grade'], bins,labels=group_names)
df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address lettergrade Status
# 0         9253 Richardson Road, Matawan, NJ 07747           B   Pass
# 1                33 Spring Dr., Taunton, MA 02780           C   Fail
# 2                41 Hill Avenue, Mentor, OH 44060           C   Fail
# 3              8839 Marshall St., Miami, FL 33125           B   Pass
# 4        8304 Charles Rd., Lewis Center, OH 43035           B   Pass
# ...                                           ...         ...    ...
# 1995        982 West Street, Alexandria, VA 22304           B   Pass
# 1996   78 Morris Street, East Northport, NY 11731           A   Pass
# 1997        30 Glenridge Rd., Bountiful, UT 84010           B   Pass
# 1998  342 West Meadowbrook Lane, Helena, MT 59601           D   Fail
# 1999       81 Homestead Drive, Voorhees, NJ 08043           C   Fail
#
# [2000 rows x 10 columns]

# %%
pd.value_counts(df['Status'])
# Out:
# Pass    1212
# Fail     788
# Name: Status, dtype: int64

# %%
#Applying Functions to Groups, Bins, and Columns
import pandas as pd
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Create the bin dividers
bins = [0, 60, 70, 80, 90, 100]
# Create names for the four groups
group_names = ['F', 'D', 'C', 'B', 'A']
df['letterGrades'] = pd.cut(df['grade'],bins, labels=group_names)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address letterGrades
# 0   9253 Richardson Road, Matawan, NJ 07747            B
# 1          33 Spring Dr., Taunton, MA 02780            C
# 2          41 Hill Avenue, Mentor, OH 44060            C
# 3        8839 Marshall St., Miami, FL 33125            B
# 4  8304 Charles Rd., Lewis Center, OH 43035            B

# %%
df.groupby('letterGrades')['hours'].mean()
# Out:
# letterGrades
# F     3.933333
# D     5.544041
# C     8.381034
# B    11.827680
# A    15.305263
# Name: hours, dtype: float64

# %%
# Applying the integer function to the grade column
df['grade'] = df['grade'] = df['grade'].apply(lambda x: int(x))
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10     82
# 1   Kadeem  Morrison    male   18         4      4     78
# 2     Nash    Powell    male   18         5      9     79
# 3  Noelani    Wagner  female   14         2      7     83
# 4  Noelani    Cherry  female   18         4     15     87
#
#                                     address letterGrades
# 0   9253 Richardson Road, Matawan, NJ 07747            B
# 1          33 Spring Dr., Taunton, MA 02780            C
# 2          41 Hill Avenue, Mentor, OH 44060            C
# 3        8839 Marshall St., Miami, FL 33125            B
# 4  8304 Charles Rd., Lewis Center, OH 43035            B

# %%
gender_preScore = df['grade'].groupby(df['gender'])
gender_preScore.mean()
# Out:
# gender
# female    82.341
# male      81.981
# Name: grade, dtype: float64

# %%
#Your Turn
import pandas as pd
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
# Create the bin dividers
bins = [0,70,100]
# Create names for the four groups
group_names = ['Fail', 'Pass']
df['status'] = pd.cut(df['grade'],bins, labels=group_names)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address status
# 1995        982 West Street, Alexandria, VA 22304   Pass
# 1996   78 Morris Street, East Northport, NY 11731   Pass
# 1997        30 Glenridge Rd., Bountiful, UT 84010   Pass
# 1998  342 West Meadowbrook Lane, Helena, MT 59601   Fail
# 1999       81 Homestead Drive, Voorhees, NJ 08043   Pass

# %%
# Create new passign_females df for 'female' and 'pass'

pass_females = df.loc[(df['gender']=='female') & (df['status']=='Pass')]
pass_females.head()
# Out:
#      fname   lname  gender  age  exercise  hours  grade  \
# 0   Marcia    Pugh  female   17         3     10   82.4
# 3  Noelani  Wagner  female   14         2      7   83.2
# 4  Noelani  Cherry  female   18         4     15   87.4
# 6    Nelle  Golden  female   17         1      9   80.2
# 8  Illiana   Rojas  female   15         5      9   76.5
#
#                                     address status
# 0   9253 Richardson Road, Matawan, NJ 07747   Pass
# 3        8839 Marshall St., Miami, FL 33125   Pass
# 4  8304 Charles Rd., Lewis Center, OH 43035   Pass
# 6     9768 Hanover Dr., Meadville, PA 16335   Pass
# 8  9425 Studebaker Dr., Thibodaux, LA 70301   Pass

# %%
pd.value_counts(pass_females['gender'])
# Out:
# female    901
# Name: gender, dtype: int64

# %%
pd.value_counts(pass_females['status'])
# Out:
# Pass    901
# Fail      0
# Name: status, dtype: int64

# %%
pass_females.exercise.mean()
# Out:
# 3.097669256381798
